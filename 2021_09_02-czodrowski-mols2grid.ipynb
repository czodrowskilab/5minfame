# %% [markdown]
# # <center> 10 minutes of fame: mols2grid </center>
#
# Author: Paul Czodrowski<br>
# Date: 02.09.2021
#
# <br>
#
# |<img align="center" width="70" height="70" src="pictures/c-lab.png"> http://www.czodrowskilab.org/|<img align="center" width="70" height="70" src="pictures/twitter.png"> http://twitter.com/czodrowskipaul|
# |:--:|:--:|
# |<img align="center" width="70" height="70" src="pictures/spotify.png"> http://www.czodrowskilab.org/music|<img align="center" width="70" height="70" src="pictures/github.png"> http://github.com/czodrowskilab|
# <br><br>

# %% [markdown]
# Inspired by Pat Walter's (https://github.com/PatWalters/chem_tutorial, https://twitter.com/wpwalters) recent talk (recorded: https://youtu.be/2ZjerAGS_IQ)

# %% [markdown]
# Pat gave a talk (slides: https://github.com/PatWalters/chem_tutorial/blob/main/2021_08_19_Chem_Tutorial.pdf; code: https://github.com/PatWalters/chem_tutorial) as part of the RSC CICAG Open Chemical Sciences workshop series.

# %% [markdown]
# As an interesting matter of fact Pat is using binder (www.mybinder.org) for direct access and execution of his notebooks (https://mybinder.org/v2/gh/PatWalters/chem_tutorial/HEAD): this is awesome!

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole 
from rdkit.Chem import Draw
from rdkit.Chem import rdDepictor
IPythonConsole.ipython_useSVG = True
rdDepictor.SetPreferCoordGen(True)
import mols2grid

# %%
mols = [x for x in Chem.SDMolSupplier("example_compounds.sdf")]

# %% [markdown]
# ## Here comes the cool thing: mols2grid for a neat display of a list of molecules
# mols2grid (https://github.com/cbouy/mols2grid) is developed by Cédric Bouysset (https://twitter.com/cedricbouysset, https://cedric.bouysset.net/) and can be simply installed via conda

# %%
mols2grid.display(mols)
# Out:
# <iframe class="mols2grid-iframe" width=100% height="946" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 820px;
#         width: 820px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 160px;
#         width: 160px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-_Name&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-_MolFileInfo&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-_MolFileComments&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-_MolFileChiralFlag&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-mols2grid-id-copy&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-SMILES&quot;&gt;Smiles&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-_Name&quot;&gt;_name&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-_MolFileInfo&quot;&gt;_molfileinfo&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-_MolFileComments&quot;&gt;_molfilecomments&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-_MolFileChiralFlag&quot;&gt;_molfilechiralflag&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-mols2grid-id&quot;&gt;Mols2grid-id&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-SMILES&#x27;, &#x27;data-_MolFileChiralFlag&#x27;, &#x27;data-_Name&#x27;, &#x27;data-mols2grid-id&#x27;, &#x27;data-_MolFileInfo&#x27;, &#x27;data-_MolFileComments&#x27;, &#x27;data-img&#x27;, &#x27;data-mols2grid-id-copy&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-SMILES&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-_Name&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-_MolFileInfo&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-_MolFileComments&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-_MolFileChiralFlag&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-mols2grid-id-copy&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 15,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-SMILES&quot;: &quot;COc1cc2c(Nc3ccc(Sc4nccn4C)c(Cl)c3)c(C#N)cnc2cc1OCCCN1CCOCC1&quot;, &quot;data-_MolFileChiralFlag&quot;: NaN, &quot;data-_Name&quot;: &quot;168691 CHEMBL318804&quot;, &quot;mols2grid-id&quot;: 0, &quot;data-_MolFileInfo&quot;: &quot;  -OEC

# %%
mols2grid.selection
# Out:
# {0: 'COc1cc2c(Nc3ccc(Sc4nccn4C)c(Cl)c3)c(C#N)cnc2cc1OCCCN1CCOCC1',
#  2: 'Cc1cnc(Nc2cccc3c2OC(F)(F)O3)nc1-c1c[nH]c(C(=O)N[C@H](CO)c2cccc(Cl)c2)c1',
#  4: 'Cc1cnc(Nc2cccc3c2CCC3)nc1-c1c[nH]c(C(=O)N[C@H](CO)c2cccc(Cl)c2)c1'}

# %% [markdown]
# Now a few more tricks I found on Cedric'c Colab notebook (https://colab.research.google.com/github/cbouy/mols2grid/blob/master/demo.ipynb):

# %%
# example dataframe
import pandas as pd

smiles = ["CCO", "c1ccccc1", "N", "CO", "O=S(=O)(-O)(-O)", "CCC", "CCC=O"]
df = pd.DataFrame({"smi": smiles,
                   "id": range(1, len(smiles) + 1)})
# setup the grid
mg = mols2grid.MolGrid(df, smiles_col="smi", size=(110, 90))
mg.display(subset=["id", "img"], n_cols=7)
# Out:
# <iframe class="mols2grid-iframe" width=100% height="188" frameborder="0" srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#       #mols2grid.gridcontainer {
#         display: block;
#         padding-left: 1em;
#         max-width: 798px;
#         width: 798px;
#       }
#       #mols2grid .cell {
#         border: 1px solid #cccccc;
#         text-align: center;
#         vertical-align: top;
#         max-width: 110px;
#         width: 110px;
#         font-family: &#x27;DejaVu&#x27;, sans-serif;
#         font-size: 12pt;
#         padding: 0;
#         margin: 0;
#         float: left;
#       }
#       #mols2grid .cell:hover {
#         background-color: #e7e7e7;
#       }
#       #mols2grid .cell img, #mols2grid .cell svg {
#         max-width: 100%;
#         height: auto;
#         padding: 0;
#       }
#       #mols2grid .data {
#         overflow: hidden;
#         white-space: nowrap;
#         text-overflow: ellipsis;
#         display: block;
#       }
#       #mols2grid .arrow-asc:after {
#         content: &#x27;↑&#x27;;
#         text-align: right;
#         float:right;
#       }
#       #mols2grid .arrow-desc:after {
#         content: &#x27;↓&#x27;;
#         text-align: right;
#         float:right;
#       }
#     &lt;/style&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/list.js/2.3.1/list.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/css/bootstrap.min.css&quot; integrity=&quot;sha384-B0vP5xmATw1+K9KRQjQERJvTumQW0nPEzvF6L/Z6nronJ3oUOFUFpCjEUQouq2+l&quot; crossorigin=&quot;anonymous&quot;&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@rdkit/rdkit@2021.3.2/Code/MinimalLib/dist/RDKit_minimal.js&quot;&gt;&lt;/script&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;mols2grid&quot; class=&quot;gridcontainer&quot;&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;div class=&quot;list&quot;&gt;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-id&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-smi&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#       &lt;/div&gt;
#       &lt;div class=&quot;row&quot;&gt;
#         &lt;ul class=&quot;pagination pt-3 pl-3 col&quot;&gt;&lt;/ul&gt;
#         &lt;div class=&quot;dropdown float-right col-1 py-3 mr-4&quot;&gt;
#           &lt;button class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; id=&quot;sortDropdown&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;
#             Sort by
#           &lt;/button&gt;
#           &lt;div class=&quot;dropdown-menu&quot; aria-labelledby=&quot;sortDropdownMenu&quot;&gt;
#
#
#             &lt;button class=&quot;dropdown-item sort-btn arrow-asc active&quot; type=&quot;button&quot; data-name=&quot;mols2grid-id&quot;&gt;Index&lt;/button&gt;
#
#
#
#             &lt;button class=&quot;dropdown-item sort-btn&quot; type=&quot;button&quot; data-name=&quot;data-id&quot;&gt;Id&lt;/button&gt;
#
#
#           &lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div class=&quot;input-group float-right col-4 py-3 mr-3 ml-2&quot;&gt;
#           &lt;input type=&quot;text&quot; id=&quot;searchbar&quot; class=&quot;form-control&quot; placeholder=&quot;Search&quot; aria-label=&quot;Search&quot; aria-describedby=&quot;basic-addon1&quot;&gt;
#           &lt;div class=&quot;input-group-append&quot;&gt;
#             &lt;button id=&quot;searchBtn&quot; class=&quot;btn btn-light dropdown-toggle&quot; type=&quot;button&quot; data-toggle=&quot;dropdown&quot; aria-haspopup=&quot;true&quot; aria-expanded=&quot;false&quot;&gt;🔎&lt;/button&gt;
#             &lt;div class=&quot;dropdown-menu dropdown-menu-right&quot;&gt;
#               &lt;button id=&quot;txtSearch&quot; class=&quot;search-btn dropdown-item active&quot;&gt;Text&lt;/button&gt;
#               &lt;button id=&quot;smartsSearch&quot; class=&quot;search-btn dropdown-item&quot;&gt;SMARTS&lt;/button&gt;
#             &lt;/div&gt;
#           &lt;/div&gt;
#         &lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;script&gt;
#       // RDKit
#       onRuntimeInitialized: initRDKitModule().then(function(instance) {
#         RDKitModule = instance;
#         console.log(&#x27;RDKit version: &#x27; + RDKitModule.version());
#       });
#       // pages
#       var listObj = new List(&#x27;mols2grid&#x27;,
#         {
#           valueNames: [{data: [&#x27;mols2grid-id&#x27;]}, &#x27;data-img&#x27;, &#x27;data-id&#x27;, &#x27;data-smi&#x27;],
#           item: &#x27;&lt;div class=&quot;cell&quot; data-mols2grid-id=&quot;0&quot;&gt;&lt;input type=&quot;checkbox&quot; class=&quot;position-relative float-left&quot;&gt;&lt;div class=&quot;data data-id&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-img&quot;&gt;&lt;/div&gt;&lt;div class=&quot;data data-smi&quot; style=&quot;display: none;&quot;&gt;&lt;/div&gt;&lt;/div&gt;&#x27;,
#           page: 21,
#           pagination: {
#             name: &quot;pagination&quot;,
#             item: &#x27;&lt;li class=&quot;page-item&quot;&gt;&lt;a class=&quot;page page-link&quot; href=&quot;#&quot; onclick=&quot;event.preventDefault()&quot;&gt;&lt;/a&gt;&lt;/li&gt;&#x27;,
#             innerWindow: 1,
#             outerWindow: 1,
#           },
#         }
#       );
#       listObj.remove(&quot;mols2grid-id&quot;, &quot;0&quot;)
#       listObj.add([{&quot;data-img&quot;: &quot;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;\n&lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;\n              xmlns=&#x27;http://www.w3.org/2000/svg&#x27;\n                      xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;\n                      xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;\n                  xml:space=&#x27;preserve&#x27;\nwidth=&#x27;110px&#x27; height=&#x27;90px&#x27; viewBox=&#x27;0 0 110 90&#x27;&gt;\n&lt;!-- END OF HEADER --&gt;\n&lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;110&#x27; height=&#x27;90&#x27; x=&#x27;0&#x27; y=&#x27;0&#x27;&gt; &lt;/rect&gt;\n&lt;path class=&#x27;bond-0&#x27; d=&#x27;M 105,51.1326 L 67.191,29.2579&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1&#x27; d=&#x27;M 67.191,29.2579 L 53.0737,37.3952&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path class=&#x27;bond-1&#x27; d=&#x27;M 53.0737,37.3952 L 38.9565,45.5324&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#FF0000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;\n&lt;path  class=&#x27;atom-2&#x27; d=&#x27;M 5 41.8988\nL 7.51594 41.8988\nL 7.51594 49.7873\nL 17.0031 49.7873\nL 17.0031 41.8988\nL 19.5191 41.8988\nL 19.5191 60.4538\nL 17.0031 60.4538\nL 17.0031 51.8839\nL 7.51594 51.8839\nL 7.51594 60.4538\nL 5 60.4538\nL 5 41.8988\n&#x27; fill=&#x27;#FF0000&#x27;/&gt;\n&lt;path  class=&#x27;atom-2&#x27; d=&#x27;M 20.8295 51.1239\nQ 20.8295 46.6686, 23.0309 44.1788\nQ 25.2324 41.6891, 29.347 41.6891\nQ 33.4616 41.6891, 35.6631 44.1788\nQ 37.8645 46.6686, 37.8645 51.1239\nQ 37.8645 55.6316, 35.6368 58.2\nQ 33.4092 60.
