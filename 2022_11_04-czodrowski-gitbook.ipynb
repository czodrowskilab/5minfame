# %% [markdown]
# ## 5 Minutes of fame at the Czodrowski lab
# Contributor: Paul Czodrowski (https://github.com/czodrowskilab, https://twitter.com/CzodrowskiPaul)
#
# Kudos to Vinith Kowrithasan (https://github.com/kowrithv, https://twitter.com/kowrithasan)
#
# Date: 2022-11-04

# %% [markdown]
# ### Is gitbook the new "Vorlesungsskript"?

# %% [markdown]
# While preparing my quantum mechanics course, I stumbled over this resource: https://kthpanor.github.io/echem/docs/title.html

# %% [markdown]
# ![echem.png](attachment:echem.png)

# %% [markdown]
# This looks amazing! [Short live demo]

# %% [markdown]
# You can do your edits here:
# https://app.gitbook.com

# %% [markdown]
# These are my cuttent attempts: https://jgu-qm.gitbook.io/untitled/
#
# What has not been working:
# * Importing a Jupyter notebook
# * Importing an entire HTML page (only the title tag has been correctly imported)

# %% [markdown]
# There is no free lunch..

# %% [markdown]
# ![gitbookprice.png](attachment:gitbookprice.png)

# %% [markdown]
# But Vinith Kowrithasan is evaluating options to make gitbook available through our centrally hosted (by JGU) gitlab. This would be amazing!
