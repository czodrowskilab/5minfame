# %% [markdown]
# # Jupyter grafiti
# ## an interactive screencast for Jupyter Notebooks

# %% [markdown]
# ### functions
#
# recordings of
# - audio
# - mouse movement
# - selection and editing of code
# - drawings, notes or highlights

# %%
import jupytergraffiti

# %% [markdown]
# # Use in exercises

# %% [markdown]
# ### Create a list of faculty names (e.g. "CCB" is one such faculty name).

# %% [markdown]
# <span class="graffiti-highlight graffiti-id_psdd4o9-id_mzk0idc"><i></i><button>Show Solution</button></span>

# %% [markdown]
# ### Create a dictionary of the faculty names (key) and the according ID (value), e.g. the ID of "CCB" is 3.

# %% [markdown]
# <span class="graffiti-highlight graffiti-id_zwsnt1y-id_xeaj5yz"><i></i><button>Show Solution</button></span>

# %% [markdown]
# # Installation of Jupyter Graffiti

# %% [markdown]
# ### 1)
# ![zero%20installation%20guide.png](attachment:zero%20installation%20guide.png)

# %% [markdown]
# ### 2)
#
# pip install jupytergraffiti
#
# or
#
# conda install -c willkessler jupytergraffiti

# %% [markdown]
# # Pros and cons

# %% [markdown]
# ### cons
#
# - recordings can take a lot of time because of retakes
# - students need to download the files with the additional data
#     - a bit more complicated to up- and download
#
# ![cons1.png](attachment:cons1.png)

# %% [markdown]
# - currently not compatible with jupyter notebook > 6.4.12
#     - harder for new students to acquire
#
#  ![cons2.png](attachment:cons2.png)

# %% [markdown]
# ### pros
#
# - improves learning experiences in tutorials
# - well recieved by students
# - can also be used in documentation of projects

# %% [markdown]
# ##### link fo Github reposition:
# https://github.com/willkessler/jupytergraffiti
